# %%
import pandas as pd
import torch
from torch import nn
from torch.utils import data
from d2l import torch as d2l

# %%
root_path = '../data/CaliforniaHousePrices/'
train_path = root_path + 'raw/train.csv'
test_path = root_path + 'raw/test.csv'

submission_path = root_path + 'submission.csv'

train_data = pd.read_csv(train_path)
test_data = pd.read_csv(test_path)

train_data.shape, test_data.shape
# Out:
# ((47439, 41), (31626, 40))

# %%
train_features_idx = list(range(4, 17)) + [18, 19, 21, 22] + list(range(24, 34)) + [35, 38]
test_features_idx = [idx - 1 for idx in train_features_idx]
all_features = pd.concat((train_data.iloc[:, train_features_idx], test_data.iloc[:, test_features_idx]))
all_features.iloc[:5, :12]
# Out:
#            Type  Year built                                       Heating  \
# 0  SingleFamily      1969.0  Heating - 2+ Zones, Central Forced Air - Gas
# 1  SingleFamily      1926.0                                   Combination
# 2  SingleFamily      1958.0                                    Forced air
# 3  SingleFamily      1947.0                                       Central
# 4    VacantLand         NaN                                           NaN
#
#                                              Cooling  \
# 0    Multi-Zone, Central AC, Whole House / Attic Fan
# 1  Wall/Window Unit(s), Evaporative Cooling, See ...
# 2                                                NaN
# 3                                        Central Air
# 4                                                NaN
#
#                                          Parking     Lot  \
# 0             Garage, Garage - Attached, Covered     1.0
# 1                       Detached Carport, Garage  4047.0
# 2                                       0 spaces  9147.0
# 3  Detached Carport, Driveway, Garage - Two Door     NaN
# 4                                       0 spaces     NaN
#
#                                             Bedrooms  Bathrooms  \
# 0  Ground Floor Bedroom, Master Bedroom on Ground...        0.0
# 1                                                  3        2.0
# 2                                                  2        3.0
# 3                                                  5        3.0
# 4                                                NaN        NaN
#
#    Full bathrooms  Total interior livable area  Total spaces  Garage spaces
# 0             NaN                          1.0           0.0            0.0
# 1             2.0                        872.0           1.0            1.0
# 2             1.0                       1152.0           0.0            0.0
# 3             3.0                       2612.0           0.0            0.0
# 4             NaN                          NaN           NaN            NaN

# %%
def get_bedrooms(s: str):
    try:
        return float(s)
    except:
        return s.count(',') + 1

all_features.Bedrooms = all_features.Bedrooms.apply(get_bedrooms)
numeric_features = all_features.dtypes[all_features.dtypes != 'object'].index
all_features[numeric_features] = all_features[numeric_features].apply(
    lambda x: (x - x.mean()) / x.std())
all_features[numeric_features] = all_features[numeric_features].fillna(0)

# %%
all_features.iloc[:5, :12]
# Out:
#            Type  Year built                                       Heating  \
# 0  SingleFamily    0.048505  Heating - 2+ Zones, Central Forced Air - Gas
# 1  SingleFamily   -0.284656                                   Combination
# 2  SingleFamily   -0.036722                                    Forced air
# 3  SingleFamily   -0.121949                                       Central
# 4    VacantLand    0.000000                                           NaN
#
#                                              Cooling  \
# 0    Multi-Zone, Central AC, Whole House / Attic Fan
# 1  Wall/Window Unit(s), Evaporative Cooling, See ...
# 2                                                NaN
# 3                                        Central Air
# 4                                                NaN
#
#                                          Parking       Lot  Bedrooms  \
# 0             Garage, Garage - Attached, Covered -0.018489  0.846659
# 1                       Detached Carport, Garage -0.018287  0.053411
# 2                                       0 spaces -0.018031 -0.739837
# 3  Detached Carport, Driveway, Garage - Two Door  0.000000  1.639906
# 4                                       0 spaces  0.000000  0.000000
#
#    Bathrooms  Full bathrooms  Total interior livable area  Total spaces  \
# 0  -2.058002        0.000000                    -0.006552     -0.135519
# 1  -0.336769       -0.106424                    -0.005198     -0.062731
# 2   0.523848       -1.167570                    -0.004763     -0.135519
# 3   0.523848        0.954722                    -0.002493     -0.135519
# 4   0.000000        0.000000                     0.000000      0.000000
#
#    Garage spaces
# 0      -0.123623
# 1      -0.050507
# 2      -0.123623
# 3      -0.123623
# 4       0.000000

# %%
# 记录待清洗Type、Heating等文本类别信息
keep_features = {}                                                                                                # merged_samples class_left
keep_features['Type'] = all_features.Type.value_counts()[all_features.Type.value_counts() >= 10].index            #            283         19
keep_features['Heating'] = all_features.Heating.value_counts()[all_features.Heating.value_counts() >= 100].index  #          10685         51
keep_features['Cooling'] = all_features.Cooling.value_counts()[all_features.Cooling.value_counts() >= 60].index   #           3640         48
keep_features['Parking'] = all_features.Parking.value_counts()[all_features.Parking.value_counts() >= 100].index  #          25104         64
keep_features['Region'] = all_features.Region.value_counts()[all_features.Region.value_counts() >= 200].index     #          32999         52
keep_features['Flooring'] = \
    all_features.Flooring.value_counts()[all_features.Flooring.value_counts() >= 100].index                       #          10223         67
keep_features['Heating features'] = \
    all_features['Heating features'].value_counts()[all_features['Heating features'].value_counts() >= 100].index #           8334         45
keep_features['Cooling features'] = \
    all_features['Cooling features'].value_counts()[all_features['Cooling features'].value_counts() >= 50].index  #           2003         40
keep_features['Appliances included'] = \
    all_features['Appliances included'].value_counts(
    )[all_features['Appliances included'].value_counts() >= 200].index                                            #          27368         48
keep_features['Laundry features'] = \
    all_features['Laundry features'].value_counts()[all_features['Laundry features'].value_counts() >= 200].index #          18845         43
keep_features['Parking features'] = \
    all_features['Parking features'].value_counts()[all_features['Parking features'].value_counts() >= 100].index #          24210         63
keep_features['City'] = all_features.City.value_counts()[all_features.City.value_counts() >= 100].index           #          25941        104

# %%
nums_to_keep = 100
print(sum(len(k) for k in keep_features.values()))
print(keep_features['City'])
# print(sum(all_features.City.value_counts()[all_features.City.value_counts() < nums_to_keep]))
# print(len(all_features.City.value_counts()[all_features.City.value_counts() >= nums_to_keep]))
print(all_features.City.value_counts())
# Out:
# 644
# Index(['Los Angeles', 'San Jose', 'San Francisco', 'San Mateo', 'San Diego',
#        'Santa Clara', 'Sunnyvale', 'Santa Cruz', 'Sacramento', 'Los Gatos',
#        ...
#        'Temecula', 'Tracy', 'Merced', 'West Covina', 'Lakewood', 'Downey',
#        'El Cajon', 'Covina', 'Roseville', 'Visalia'],
#       dtype='object', length=104)
# Los Angeles      11918
# San Jose          7030
# San Francisco     5744
# San Mateo         1125
# San Diego         1108
#                  ...
# El Nido              1
# Redcrest             1
# Mineral              1
# Independence         1
# McKittrick           1
# Name: City, Length: 1122, dtype: int64

# %%
type(all_features['Laundry features'][35630]) is float   # nan
# Out:
# True

# %%
# 合并低数据量文本类别信息
for col, keep_feature in keep_features.items():
    all_features[col] = all_features[col].apply(
        lambda x: x if x in keep_feature or type(x) is float else 'Other')
all_features.Type.value_counts()
# Out:
# SingleFamily          53521
# Condo                 12794
# Townhouse              4096
# MultiFamily            2258
# Unknown                2168
# MobileManufactured     1577
# VacantLand             1510
# Single Family           362
# Other                   283
# Apartment               191
# Cooperative             100
# Residential Lot          59
# MFD-F                    38
# 2 Story                  20
# Acreage                  19
# Condominium              19
# Duplex                   16
# 3 Story                  12
# Manufactured Home        12
# Vacant Land              10
# Name: Type, dtype: int64

# %%
all_features['Cooling features'].value_counts(dropna=False)
# Out:
# Central Air                                     18582
# Central                                         16852
# NaN                                             16633
# None                                            15484
# Other                                            3328
# Wall/Window Unit(s)                              1474
# Wall                                              837
# Central Air, Electric                             473
# See Remarks                                       407
# Ceiling Fan(s), Central Air                       370
# Central, Solar                                    365
# Central Air, Dual                                 354
# Evaporative                                       318
# Ceiling Fan(s)                                    316
# Zoned                                             293
# No Air Conditioning                               279
# Evaporative Cooling                               234
# Central, Other                                    206
# Central Air, Gas                                  191
# Central Air, Zoned                                185
# Central Air, Whole House Fan                      119
# Central, Wall                                     118
# AC Central                                        115
# Refrigerator                                      113
# Central Air, ENERGY STAR Qualified Equipment      110
# Central Air, Attic Fan                            109
# Central Air, See Remarks                          108
# Ceiling Fan(s), Zoned                             108
# Central Air, Wall/Window Unit(s)                  107
# Refrigerator, Central                              97
# Central Air/Refrig                                 93
# Heat Pump                                          89
# Dual                                               83
# Electric                                           78
# Central Air, Dual, Zoned                           77
# Central, Evaporative                               74
# Central Air, Evaporative Cooling                   67
# Ceiling Fan(s), No Air Conditioning                57
# Central Air, High Efficiency                       55
# AC Central, Ceiling Fans                           54
# Wall/Window Unit(s), Electric                      53
# Name: Cooling features, dtype: int64

# %%
all_features = pd.get_dummies(all_features, dummy_na=True)
all_features.shape
# Out:
# (79065, 680)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %%
n_train = train_data.shape[0]
train_features = torch.tensor(all_features[:n_train].values, dtype=torch.float32).to(device)
test_features = torch.tensor(all_features[n_train:].values, dtype=torch.float32).to(device)
train_labels = torch.tensor(train_data['Sold Price'].values.reshape(-1, 1), dtype=torch.float32).to(device)

train_features.shape, train_labels.shape, train_features.device
# Out:
# (torch.Size([47439, 680]),
#  torch.Size([47439, 1]),
#  device(type='cuda', index=0))

# %%
loss = nn.MSELoss()
in_features = train_features.shape[1]

def get_net():
    net = nn.Sequential(nn.Linear(in_features, 1))
    return net.to(device)

# %%
def log_rmse(net, features, labels):
    clipped_preds = torch.clamp(net(features), 1, float('inf'))
    rmse = torch.sqrt(loss(torch.log(clipped_preds), torch.log(labels)))
    return rmse.item()

# %%
def train(net, train_features, train_labels, test_features, test_labels, num_epochs, learning_rate, weight_decay, batch_size):
    train_ls, test_ls = [], []
    dataset = data.TensorDataset(train_features, train_labels)
    train_iter = data.DataLoader(dataset, batch_size)
    optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate, weight_decay=weight_decay)
    for epoch in range(num_epochs):
        for X, y in train_iter:
            optimizer.zero_grad()
            l = loss(net(X), y)
            l.backward()
            optimizer.step()
        train_ls.append(log_rmse(net, train_features, train_labels))
        if test_labels is not None:
            test_ls.append(log_rmse(net, test_features, test_labels))
    return train_ls, test_ls

# %%
def get_k_fold_data(k, i, X, y):
    assert k > 1
    fold_size = X.shape[0] // k
    X_train, y_train = None, None
    for j in range(k):
        idx = slice(j * fold_size, (j + 1) * fold_size)
        X_part, y_part = X[idx, :], y[idx]
        if j == i:
            X_valid, y_valid = X_part, y_part
        elif X_train is None:
            X_train, y_train = X_part, y_part
        else:
            X_train = torch.cat([X_train, X_part], 0)
            y_train = torch.cat([y_train, y_part], 0)
    return X_train, y_train, X_valid, y_valid

# %%
def k_fold(k, X_train, y_train, num_epochs, learning_rate, weight_decay, batch_size):
    train_l_sum, valid_l_sum = 0, 0
    for i in range(k):
        data = get_k_fold_data(k, i, X_train, y_train)
        net = get_net()
        train_ls, valid_ls = train(net, *data, num_epochs, learning_rate, weight_decay, batch_size)
        train_l_sum += train_ls[-1]
        valid_l_sum += valid_ls[-1]
        if i == 0:
            d2l.plot(list(range(1, num_epochs + 1)), [train_ls, valid_ls], xlabel='epoch', ylabel='rmse',
                     xlim=[1, num_epochs], legend=['train', 'valid'], yscale='log')
        print(f'fold {i + 1}, train log rmse {float(train_ls[-1]):f}, '
              f'valid log rmse {float(valid_ls[-1]):f}')
    return train_l_sum / k, valid_l_sum / k

# %%
k, num_epochs, lr, weight_decay, batch_size = 5, 70, 5, 0, 128
train_l, valid_l = k_fold(k, train_features, train_labels, num_epochs, lr, weight_decay, batch_size)
print(f'{k}-折验证：平均训练 log rmse {float(train_l):f}, '
      f'平均验证 log rmse {float(valid_l):f}')
# Out:
# fold 1, train log rmse 0.918079, valid log rmse 0.742615
# fold 2, train log rmse 0.929974, valid log rmse 0.785298
# fold 3, train log rmse 0.910242, valid log rmse 0.966187
# fold 4, train log rmse 0.920115, valid log rmse 1.052993
# fold 5, train log rmse 0.943560, valid log rmse 1.067450
# 5-折验证：平均训练 log rmse 0.924394, 平均验证 log rmse 0.922909

# %%
def train_and_pred(train_features, test_features, train_labels, test_data, num_epochs, lr, weight_decay, batch_size):
    net = get_net()
    train_ls, _ = train(net, train_features, train_labels, None, None, num_epochs, lr, weight_decay, batch_size)
    d2l.plot(list(range(1, num_epochs + 1)), [train_ls], xlabel='epoch', ylabel='log rmse', xlim=[1, num_epochs], yscale='log')
    print(f'train log rmse {float(train_ls[-1]):f}')
    preds = net(test_features).cpu().detach().numpy()
    test_data['Sold Price'] = pd.Series(preds.reshape(1, -1)[0])
    submission = pd.concat([test_data['Id'], test_data['Sold Price']], axis=1)
    submission.to_csv(submission_path, index=False)

train_and_pred(train_features, test_features, train_labels, test_data, num_epochs, lr, weight_decay, batch_size)
# Out:
# train log rmse 0.934001
